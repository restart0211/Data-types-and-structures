# %% [markdown]
# THEORY QUESTIONS
#
#
# ANSWER 1)
# Data structures are fundamental in computer science, acting as specialized formats for organizing, storing, and accessing data efficiently within a computer system.
#
# Data structures are important:
# Efficiency:
# Data structures are designed to optimize operations like searching, sorting, and manipulating data. By choosing the right data structure, you can significantly reduce the time and resources needed to perform these operations.
# Organization:
# They provide a structured way to arrange data, making it easier to access, update, and retrieve information when needed.
#
# Problem Solving:
# Understanding different data structures and their strengths enables developers to solve complex problems more effectively.
#
# Real-world Applications:
# Data structures are used in a wide range of applications, including databases, operating systems, compilers, and various software systems.

# %% [markdown]
# ANSWER 2) Mutable data types can be changed after they are created, while immutable data types cannot be modified once they are initialized. Examples of mutable data types include lists and dictionaries, while examples of immutable data types include strings and tuples.

# %% [markdown]
# ANSWER 3)The main differences between lists and tuples in Python are:
#
# Mutability: Lists are mutable, meaning their elements can be changed after creation (elements can be added, removed, or modified). Tuples are immutable, meaning their elements cannot be changed after creation.
#
# Syntax: Lists are defined using square brackets [], while tuples are defined using parentheses ().
#
# Use Cases: Lists are suitable for collections of items that may need to be modified. Tuples are suitable for collections of items that should remain constant.

# %% [markdown]
# ANSWER 4 )Dictionaries are used to store data values in key:value pairs. A dictionary is a collection which is ordered*, changeable and do not allow duplicates.

# %% [markdown]
# ANSWER 5)Because sets cannot have multiple occurrences of the same element, it makes sets highly useful to efficiently remove duplicate values from a list or tuple and to perform common math operations like unions and intersections.

# %% [markdown]
# ANSWER 6)A string is a sequence of characters between single or double quotes. A list is a sequence of items, where each item could be anything
# Strings have a fixed length, while lists can dynamically grow or shrink in size by adding or removing elements

# %% [markdown]
# ANSWER 7) Tuples in Python ensure data integrity primarily through their immutability. Once a tuple is created, its contents cannot be changed, added to, or removed.
#
# Immutability ensures that data stored in a tuple remains constant throughout its lifecycle. This prevents unintended alterations that could lead to errors or inconsistencies, especially in scenarios where data integrity is critical, such as configuration settings or database records.
#
# Tuples can be used as keys in dictionaries because they are immutable and hashable. If tuples were mutable, their hash values could change, making them unreliable as dictionary keys.

# %% [markdown]
# ANSWER 8 )In Python, the Dictionary data types represent the implementation of hash tables. The Keys in the dictionary are hashable–they are generated by a hash function which generates a unique result for each unique value supplied to the hash function.

# %% [markdown]
# ANSWER 9)Yes, lists in Python can contain different data types. Python lists are versatile and allow you to store elements of various types within the same list. This includes integers, floats, strings, booleans, and even other lists or data structures like dictionaries and tuples.

# %% [markdown]
# ANSWER 10)Python strings are immutable which means they cannot be changed after they are created . Since strings can't be changed, we construct new strings as we go to represent computed values.

# %% [markdown]
# ANSWER 11)A list can store any data type. In contrast, keys in the dictionary can be of any immutable data type, and values can be of any data type. Lists perform faster for ordered operations like sorting, while dictionaries perform faster for lookup operations.

# %% [markdown]
# ANSWER 12)uples are immutable. Hence, they are primarily used to store data that doesn't change frequently. Any operation can store data in a tuple when you don't want it to change. Tuples are great to use if you want the data in your collection to be read-only, never to change, and always remain the same and constant.

# %% [markdown]
# ANSWER 13)In Python, sets are designed to store only unique elements. When attempting to add a duplicate value to a set, the set automatically discards the duplicate, ensuring that each element within the set is unique. This behavior makes sets a useful tool for removing duplicates from other data structures like lists or tuples. If a set is initialized with duplicate values or if duplicate values are added later, only one instance of each unique value will be retained in the set.

# %% [markdown]
# ANSWER 14)the in operation for the dictionary tests on keys. The key of the dictionary is a unique value as well as the set, and the execution time is about the same as for sets. On the other hand, dictionary values can be duplicated like a list.

# %% [markdown]
# ANSWER 15)No, you cannot directly modify the elements of a tuple in Python. Tuples are immutable data structures, meaning their elements cannot be changed after they are created. Attempting to assign a new value to an element within a tuple will raise a TypeError

# %% [markdown]
# ANSWER 16)A nested dictionary in Python is a dictionary where the values are themselves dictionaries. This allows for structuring data in a hierarchical way, where you can store complex, multi-layered information. A common use case is representing hierarchical data like family trees or organizational chart

# %% [markdown]
# ANSWER 17)The time complexity of accessing an element in a dictionary is typically O(1), meaning it takes constant time regardless of the dictionary's size. This is because dictionaries use hashing to map keys to their corresponding values, allowing for direct access to the desired value in a single step.

# %% [markdown]
# ANSWER 18)For quick data look-ups, configurations, or caches, favor dictionaries. For ordered collections and sequence operations, such as maintaining a stack or queue, lists are more suitable

# %% [markdown]
# ANSWER 19 )A dictionary is termed an unordered collection of objects because dictionaries do not maintain any inherent order of the items based on when they were added.

# %% [markdown]
# ANSWER 20)Difference betgween lists and dictionaries:
#
# Lists:
# Elements are accessed by their position (index) in the sequence.
# Retrieval time is proportional to the list's size, as elements need to be checked one by one.
# Best for ordered collections where you know the position of the desired element.
#
#
# Dictionaries:
# Elements are accessed by their associated key.
# Retrieval time is very fast (close to O(1) or constant time) due to the use of a hash table.
# Ideal for scenarios where you need to quickly look up data based on a unique identifier.

# %% [markdown]
# **PRACTICAL QUESTIONS**

# %% [markdown]
# ANSWER 1)

# %%
my_name = "Suyash"
print("My name is:", my_name)
# Out:
# My name is: Suyash

# %% [markdown]
# ANSWER 2)

# %%
text = "Hello World"
length = len(text)
print("Length of the string is:", length)
# Out:
# Length of the string is: 11

# %% [markdown]
# ANSWER 3)

# %%
text = "Python Programming"
sliced_text = text[:3]
print("First 3 characters are:", sliced_text)
# Out:
# First 3 characters are: Pyt

# %% [markdown]
# ANSWER 4)

# %%
text = "hello"
uppercase_text = text.upper()
print("Uppercase version:", uppercase_text)
# Out:
# Uppercase version: HELLO

# %% [markdown]
# ANSWER 5)

# %%
text = "I like apple"
new_text = text.replace("apple", "orange")
print("Updated string:", new_text)
# Out:
# Updated string: I like orange

# %% [markdown]
# ANSWER 6)

# %%
numbers = [1, 2, 3, 4, 5]
print("The list is:", numbers)
# Out:
# The list is: [1, 2, 3, 4, 5]

# %% [markdown]
# ANSWER 7)

# %%
numbers = [1, 2, 3, 4]
numbers.append(10)
print("Updated list:", numbers)
# Out:
# Updated list: [1, 2, 3, 4, 10]

# %% [markdown]
# ANSWER 8 )

# %%
numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print("Updated list:", numbers)
# Out:
# Updated list: [1, 2, 4, 5]

# %% [markdown]
# ANSWER 9)

# %%
letters = ['a', 'b', 'c', 'd']
second_element = letters[1]
print("The second element is:", second_element)
# Out:
# The second element is: b

# %% [markdown]
# ANSWER 10)

# %%
numbers = [10, 20, 30, 40, 50]
reversed_numbers = numbers[::-1]
print("Reversed list:", reversed_numbers)
# Out:
# Reversed list: [50, 40, 30, 20, 10]

# %% [markdown]
# ANSWER 11 )

# %%
my_tuple = (100, 200, 300)
print("The tuple is:", my_tuple)
# Out:
# The tuple is: (100, 200, 300)

# %% [markdown]
# ANSWER 12)

# %%
colors = ('red', 'green', 'blue', 'yellow')
second_to_last = colors[-2]
print("The second-to-last element is:", second_to_last)
# Out:
# The second-to-last element is: blue

# %% [markdown]
# ANSWER 13

# %%
numbers = (10, 20, 5, 15)
min_number = min(numbers)
print("The minimum number is:", min_number)
# Out:
# The minimum number is: 5

# %% [markdown]
# ANSWER 14)

# %%
animals = ('dog', 'cat', 'rabbit')
index_of_cat = animals.index('cat')
print("The index of 'cat' is:", index_of_cat)
# Out:
# The index of 'cat' is: 1

# %% [markdown]
# ANSWER 15 )

# %%
fruits = ('apple', 'banana', 'cherry')
is_kiwi_in_tuple = 'kiwi' in fruits
print("Is 'kiwi' in the tuple?", is_kiwi_in_tuple)
# Out:
# Is 'kiwi' in the tuple? False

# %% [markdown]
# ANSWER 16)

# %%
my_set = {'a', 'b', 'c'}
print("The set is:", my_set)
# Out:
# The set is: {'b', 'a', 'c'}

# %% [markdown]
# ANSWER 17 )

# %%
my_set = {1, 2, 3, 4, 5}
my_set.clear()
print("Set after clearing:", my_set)
# Out:
# Set after clearing: set()

# %% [markdown]
# ANSWER 18)

# %%
my_set = {1, 2, 3, 4}
my_set.remove(4)
print("Set after removing 4:", my_set)
# Out:
# Set after removing 4: {1, 2, 3}

# %% [markdown]
# ANSWER 19)

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1 | set2
print("Union of the two sets:", union_set)
# Out:
# Union of the two sets: {1, 2, 3, 4, 5}

# %% [markdown]
# ANSWER 20 )

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}
intersection_set = set1 & set2
print("Intersection of the two sets:", intersection_set)
# Out:
# Intersection of the two sets: {2, 3}

# %% [markdown]
# ANSWER 21)

# %%
my_dict = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}
print("The dictionary is:", my_dict)
# Out:
# The dictionary is: {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %% [markdown]
# ANSWER 22)

# %%
my_dict = {'name': 'John', 'age': 25}
my_dict["country"] = "USA"
print("Updated dictionary:", my_dict)
# Out:
# Updated dictionary: {'name': 'John', 'age': 25, 'country': 'USA'}

# %% [markdown]
# ANSWER 23)

# %%
my_dict = {'name': 'Alice', 'age': 30}
name_value = my_dict["name"]
print("The value associated with 'name' is:", name_value)
# Out:
# The value associated with 'name' is: Alice

# %% [markdown]
# ANSWER 24)

# %%
my_dict = {'name': 'Bob', 'age': 22, 'city': 'New York'}
del my_dict["age"]
print("Updated dictionary:", my_dict)
# Out:
# Updated dictionary: {'name': 'Bob', 'city': 'New York'}

# %% [markdown]
# ANSWER 25)

# %%
my_dict = {'name': 'Alice', 'city': 'Paris'}
if "city" in my_dict:
    print("The key 'city' exists in the dictionary.")
else:
    print("The key 'city' does not exist in the dictionary.")
# Out:
# The key 'city' exists in the dictionary.

# %% [markdown]
# ANSWER 26)

# %%
my_list = [1, 2, 3, 4, 5]

my_tuple = ('apple', 'banana', 'cherry')


my_dict = {'name': 'John', 'age': 25, 'city': 'New York'}


print("List:", my_list)
print("Tuple:", my_tuple)
print("Dictionary:", my_dict)
# Out:
# List: [1, 2, 3, 4, 5]
# Tuple: ('apple', 'banana', 'cherry')
# Dictionary: {'name': 'John', 'age': 25, 'city': 'New York'}

# %% [markdown]
# ANSWER 28)

# %%
my_list = ['apple', 'banana', 'cherry', 'date', ]

# Printing the element at the third index
print("Element at index 3:", my_list[3])
# Out:
# Element at index 3: date

# %% [markdown]
# ANSWER 29)

# %%
dict1 = {'name': 'Alice', 'age': 25}
dict2 = {'city': 'Paris', 'country': 'France'}


combined_dict = {**dict1, **dict2}


print("Combined dictionary:", combined_dict)
# Out:
# Combined dictionary: {'name': 'Alice', 'age': 25, 'city': 'Paris', 'country': 'France'}

# %% [markdown]
# ANSWER 30 )

# %%
my_list = ['apple', 'banana', 'cherry', 'apple', 'date']


my_set = set(my_list)


print("Converted set:", my_set)
# Out:
# Converted set: {'cherry', 'date', 'apple', 'banana'}

# %% [markdown]
# ANSWER 27 )

# %%
n = 5
li = random.sample(range(1, 101), n)
print(li)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f0fa79b3376b> in <cell line: 0>()
#       1 n = 5
# ----> 2 li = random.sample(range(1, 101), n)
#       3 print(li)
#
# NameError: name 'random' is not defined
